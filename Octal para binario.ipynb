# %%
binCent = ""
binDez = ""
binUni = ""

resCent = ""
resDez = ""
resUni = ""

octal = int(input("Informe um numero em octal para ser convertido em binario: "))

cent = int(octal / 100)
dez = int(((octal / 100) - (float(cent))) * 10)
uni = int(((((octal / 100) - (float(cent))) * 10) - (float(dez))) * 10 )

print("A parte da centena é:", cent)
print("A parte da dezena é:", dez)
print("A parte da unidade é:", uni)

if((cent < 0) or (cent == 8)):
    print("INVÁLIDO")
elif(cent == 0):
    binCent = "0"
    print("Parte Centena: ", binCent)
elif(cent == 1):
    binCent = "1"
    print("Parte Centena: ", binCent)
elif(cent == 2):
    binCent = "010"
    print("Parte Centena: ", binCent)
elif(cent == 3):
    binCent = "011"
    print("Parte Centena: ", binCent)
elif(cent > 3):
    while(cent != 1):
        binCent += str(cent % 2)
        cent = cent // 2
        if(cent // 2 == 1):
            binCent += str(cent % 2) + str(cent // 2)
        elif(cent // 2 == 0):
            binCent += str(cent % 2) + str(cent // 2)
            break
        for i in range(len(binCent) -1, -1, -1):
            resCent += binCent[i]
        print("A parte da centena em binário é: ", resCent)

if(dez < 0) or (dez == 8):
    print("INVÁLIDO")
elif(dez == 0):
    binDez = "0"
    print("Parte da dezena é: ", binDez)
elif( dez == 1):
    binDez = "1"
    print("Parte da dezena é: ", binDez)
elif( dez == 2):
    binDez = "010"
    print("Parte da dezena é: ", binDez)
elif(dez == 3):
    binDez = "011"
    print("Parte da dezena é: ", binDez)
elif(dez > 3):
    while(dez != 1):
        binDez += str(dez % 2)
        dez = dez // 2
        if(dez // 2 == 1):
            binDez += str(dez % 2 ) + str(dez // 2)
        elif(dez // 2 == 0):
            binDez += str(dez % 2) + str(dez // 2)
            break
        for i in range(len(binDez)-1, -1, -1):
            resDez += binDez[i]
    print("A parte da dezena é: ", resDez)

if(uni < 0) or (uni == 8):
    print("INVÁLIDO")
elif(uni == 0):
    binUni = "0"
    print("Parte da unidade é:", binUni)
elif(uni == 1):
    binUni == "1"
    print("Parte da unidade é:", binUni)
elif(uni == 2):
    binUni = "010"
    print("Parte da unidade é:", binUni)
elif(uni == 3):
    binUni = "011"
    print("Parte da unidade é:", binUni)
elif(uni > 3):
    while(uni != 1):
        binUni += str(uni % 2)
        uni = uni // 2
        if(uni // 2 == 1):
            binUni += str(uni % 2) + str(uni // 2)
        elif(uni // 2 == 0):
            binUni += str(uni % 2) + str(uni // 2)
            break
        for i in range(len(binUni)-1, -1, -1):
            resUni += binUni[i]
        print("Parte unidade: ", resUni)
        
if((cent == 0) and (dez != 0) and (uni != 0)):
    print(binCent, resDez, resUni)
elif((cent == 1) and (dez != 1) and (uni != 1)):
    print(binCent, resDez, resUni)
elif((cent == 2) and (dez != 2) and (uni != 2)):
    print(binCent, resDez, resUni)
elif((cent == 3) and (dez != 3) and (uni != 3)):
    print(binCent, resDez, resUni)

    
if((cent != 0) and(dez == 0) and (uni != 0)):
    print(resCent, binDez, resUni)
elif((cent != 1) and (dez == 1) and (uni != 1)):
    print(resCent, binDez, resUni)
elif((cent != 2) and (dez == 2) and (uni != 2)):
    print(resCent, binDez, resUni)
elif(cent != 3) and (dez == 3) and (uni != 3):
    print(resCent, binDez, resUni)


if((cent != 0) and (dez != 0) and (uni == 0)):
    print(resCent, resDez, binUni)
elif((cent != 1) and (dez != 1) and (uni == 1)):
    print(resCent, resDez, binUni)
elif((cent != 2) and (dez != 2 ) and (uni == 2)):
    print(resCent, resDez, binUni)
elif((cent != 3) and (dez != 3) and (uni == 3)):
    print(resCent, resDez, binUni)

if((cent == 0) and (dez == 0) and (uni == 0)):
    print(binCent, binDez , binUni)
    
elif((cent == 1) and (dez == 1 ) and ( uni == 1)):
    print(binCent, binDez , binUni) 

elif((cent == 2) and (dez == 2) and (uni == 2)):
    print(binCent, binDez , binUni) 
     
elif((cent == 3) and (dez == 3) and (uni == 3)):
    print(binCent, binDez , binUni) 



if((cent > 3) and (dez > 3) and (uni > 3)):
 print(resCent, resDez , resUni)
# Out:
# Informe um numero em octal para ser convertido em binario: 536
# A parte da centena é: 5
# A parte da dezena é: 3
# A parte da unidade é: 6
# A parte da centena em binário é:  101
# Parte da dezena é:  011
# Parte unidade:  110
# 101 011 110
