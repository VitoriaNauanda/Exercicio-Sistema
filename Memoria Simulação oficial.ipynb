# %%
ListaDados = ["00000000", "00000000", "00000000", "00000000", "00000000", "00000000", "00000000", "00000000", "00000000", "00000000", "00000000", "00000000", "00000000", "00000000", "00000000", "00000000"]



while True:
      print(" ")  
      tecla = input("Digite W para escrever, R para ler, L para listar e qualquer tecla para parar: ")
      print(" ")
      if(tecla == "W"):
         endereco = (input("Digite um Endereço de 4 bits: "))

         teste = True
         while(teste == True):
          teste = False
          for i in range(len(endereco)):
             if(endereco[i] != "0" and endereco[i] != "1"):
               teste = True
               print(" ")
               print("O Endereço só deve ter numeros binarios de 4 bits")
               print(" ")
               endereco = (input("Digite um Endereço de 4 bits: "))
               break;
        
         while(len(endereco) != 4):
              print(" ")
              print("O Endereço deve ter apenas 4 bits ! ")
              print(" ")
              endereco = (input("Digite um Endereço de 4 bits: "))
              teste = True
              while(teste == True):
                  teste = False
                  for i in range(len(endereco)):
                      if(endereco[i] != "0" and endereco[i] != "1"):
                          teste = True
                          print(" ")
                          print("O Endereço só deve ter numeros binarios de 4 bits")
                          print(" ")
                          endereco = input("Digite um Endereço de 4 bits: ")
                      break;
         for i in range(len(endereco)):
             
            potencia = len(endereco)
            
              
         indice = 0
       
      
         for i in range(len(endereco)):
           
           potencia = potencia - 1 
           indice = indice + ((int(endereco[i])) * (2 ** potencia))

         dado = input("Digite um dado de 8 bits: ")
         while(len(dado) != 8):
            print(" ")
            print("O Dado só deve ter numeros binarios de 8 bits !")
            print(" ")
            dado = input("Digite um Dado de 8 bits: ")
            teste1 = True
            while(teste1 == True):
                teste1 = False
                for i in range(len(dado)):
                    if(dado[i] != "0" and dado[i] != "1"):
                        teste1 = True
                        print("")
                        print("O dado só deve ter numeros binarios de 8 bits")
                        print("")
                        dado = input("Digite um dado de 8 bits: ")
                    break;    

         ListaDados[indice] = dado


      elif(tecla == "R"):
          endereco = input("Digite o Endereço: ")
          while True: 
           for i in range(len(endereco)):
             if(endereco[indice] != "0" and endereco[indice] != "1"):
               print(" ")
               print("O Endereço só deve ter numeros binarios de 4 bits")
               print(" ")
               endereco = (input("Digite um Endereço de 4 bits: "))
           break;
         
          while(len(endereco) != 4):
              print(" ")
              print("O Endereço só deve ter numeros binarios 4 bits! ")
              print(" ")
              endereco = input("Digite o Endereço: ")
              teste = True
              while(teste == True):
                  teste = False
                  for i in range(len(endereco)):
                      if(endereco[i] != "0" and endereco[i] != "1"):
                         teste = True
                         print(" ")
                         print("O Endereço só deve ter numeros binarios de 4 bits")
                         print(" ")
                         print("Digite um Endereço de 4 bits: ")
                      break;
          for i in range(len(endereco)):
             
            potencia = len(endereco)

          indice = 0
          for i in range(len(endereco)):
           potencia = potencia - 1 
           indice = indice + ((int(endereco[i])) * (2 ** potencia))
          print(ListaDados[indice])


      elif(tecla == "L"):
          print("Todos os Estados :")
        
          for i in range (len(ListaDados)):  
            print(ListaDados[i])
      else:
          print("Parar execução")
          break;
# Out:
#
# Digite W para escrever, R para ler, L para listar e qualquer tecla para parar: W
#
# Digite um Endereço de 4 bits: ABCD
#
# O Endereço só deve ter numeros binarios de 4 bits
#
# Digite um Endereço de 4 bits: 000N
#
# O Endereço só deve ter numeros binarios de 4 bits
#
# Digite um Endereço de 4 bits: 0
#
# O Endereço deve ter apenas 4 bits !
#
# Digite um Endereço de 4 bits: 0000
# Digite um dado de 8 bits: ABCDFGH
#
# O Dado só deve ter numeros binarios de 8 bits !
#
# Digite um Dado de 8 bits: 01
#
# O Dado só deve ter numeros binarios de 8 bits !
#
# Digite um Dado de 8 bits: 11001100
#
# Digite W para escrever, R para ler, L para listar e qualquer tecla para parar: W
#
# Digite um Endereço de 4 bits: 0011
# Digite um dado de 8 bits: 11111111
#
# Digite W para escrever, R para ler, L para listar e qualquer tecla para parar: L
#
# Todos os Estados :
# 11001100
# 00000000
# 00000000
# 11111111
# 00000000
# 00000000
# 00000000
# 00000000
# 00000000
# 00000000
# 00000000
# 00000000
# ...
